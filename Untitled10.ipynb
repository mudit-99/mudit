# %%
x=input("DNA SEQUENCE: \n ")
print("REVERSE SEQUENCE FOR PROVIDED DNA IS: \n")
def reverse(x): 
    if len(x) == 0: 
        return x
    else: 
        return reverse(x[1:]) + x[0] 
print (reverse(x))


UpperCase_DNA = x.upper() 
print ('Your DNA entry is : \n', UpperCase_DNA) 


print ('The  complement of your entry sequence is :') 
for i in UpperCase_DNA:
 if (i == "A"): print ("T", end = "") 
 elif (i == "T"): print("A" , end = "")
 elif (i == "C"): print("G" , end = "")
 elif (i == "G"): print("C", end = "")
  

print("    ")


print ('The  mRNA of your entry sequence is :') 
for i in x:
 if (i == "A"): print ("A", end = "") 
 elif (i == "T"): print("U" , end = "")
 elif (i == "C"): print("C" , end = "")
 elif (i == "G"): print("G", end = "")
 #TRANSCRIPTION
 print("transcription")
x=input("enter DNA sequence :")
A=str("A")
T=str("T")
G=str("G")
C=str("C")
for i in x:
    if i==A:
        print("U", end=" ")
    elif i==T:
        print("A" , end=" ")
    elif i==G:
        print("C" , end=" ")
    elif i==C:
        print("G" ,end=" ")
#TRANSLATION
print("translation")
x=input("enter rna sequence :")
print(x[0:3])
print(x[3:6])
print(x[6:9])
print(x[9:12])
print(x[12:15])
a=(x[0:3])
b=(x[3:6])
c=(x[6:9])
d=(x[9:12])
e=(x[12:15])
UUU=str("UUU")
AUG=str("AUG")
UUG=str("UUG")
UUA=str("UUA")
CUU=str("CUU")
CUC=str("CUC")
CUA=str("CUA")
CUG=str("CUG")
AUU=str("AUU")
AUC=str("AUC")
AUA=str("AUA")
GUU=str("GUU")
GUC=str("GUC")
GUA=str("GUA")
GUG=str("GUG")
UCU=str("UCU")
UCC=str("UCC")
UCA=str("UCA")
UCG=str("UCG")
CCU=str("CCU")
CCC=str("CCC")
UCA=str("UCA")
UCG=str("UCG")
CCU=str("CCU")
CCC=str("CCC")
CCA=str("CCA")
CCG=str("CCG")
ACU=str("ACU")
ACC=str("ACC")
ACA=str("ACA")
ACG=str("ACG")
GCU=str("GCU")
GCC=str("GCC")
GCA=str("GCA")
GCG=str("GCG")
UAU=str("UAU")
UAC=str("UAC")
UAA=str("UAA")
UAG=str("UAG")
CAU=str("CAU")
CAC=str("CAC")
CAA=str("CAA")
CAG=str("CAG")
AAU=str("AAU")
AAC=str("AAC")
AAA=str("AAA")
AAG=str("AAG")
GAU=str("GAU")
GAC=str("GAC")
GAA=str("GAA")
GAG=str("GAG")
UGU=str("UGU")
UGC=str("UGC")
UGA=str("UGA")
UGG=str("UGG")
CGU=str("CGU")
CGC=str("CGC")
CGA=str("CGA")
CGG=str("CGG")
AGU=str("AGU")
AGC=str("AGC")
AGA=str("AGA")
AGG=str("AGG")
GGU=str("GGU")
GGC=str("GGC")
GGA=str("GGA")
GGG=str("GGG")
if a==UUU:
    print("phenyalanine")
elif a==AUG:
    print("methionine")
elif a==UUA or a==UUG:
    print("leucine")
if b==UUU:
    print("phenylalanine")
elif b==AUG:
    print("methionine")
elif b==UUA or b==UUG:
    print("leucine")
if c==UUU:
    print("phenylalanine")
elif c==AUG:
    print("methionine")
elif c==UUA or c==UUG:
    print("leucine")
elif x==UGA or x==UAA:
    print("stop codon")
elif x==UAG:
    print("stop codon")
elif x==UUA or x==UUG:
    print("leucine")
elif x==CUU or x==CUC:
    print("leucine")
elif x==CUA or x==CUG:
    print("luecine")
elif x==AUU or x==AUC:
    print("isoleucine")
elif x==AUA:
    print("isoleucine")
elif x==GUU or x==GUC:
    print("valine")
elif x==GUA or x==GUG:
    print("valine")

elif x==CCU or x==CCC:
    print("proline")
elif x==CCA or x==CCG:
    print("proline")
elif x==ACU or x==ACC:
    print("threonine")
elif x==ACA or x==ACG:
    print("threonine")
elif x==GCU or x==GCC:
    print("alanine")
elif x==GCA or x==GCG:
    print("alanine")
elif x==UAU or x==UAC:
    print("tyrosine")
elif x==CAU or x==CAC:
    print("histidine")
elif x==CAA or x==CAG:
    print("glutamine")
elif x==AAU or x==AAC:
    print("asparagine")
elif x==AAA or x==AAG:
    print("lysine")
elif x==GAU or x==GAC:
    print("asparagine")
elif x==GAA or x==GAG:
    print("glutamic acid")
elif x==UGU or x==UGC:
    print("cysteine")
elif x==UGG:
    print("typtophan")
elif x==CGU or x==CGC:
    print("argenine")
elif x==CGA or x==CGG:
    print("argenine")
elif x==AGU or x==AGC:
    print("serine")
elif x==AGA or x==AGC:
    print("argenine")
elif x==GGU or x==GGC:
    print("glycine")
elif x==GGA or x==GGG:
    print("glycine")
elif x==UCU or x==UCC:
    print("serine")
elif x==UCA or UCG:
    print("serine")
#CODONS
print("codons")
x=input("enter codon :")
A=str("A")
U=str("U")
G=str("G")
c=str("C")
AUG=str("AUG")
UUU=str("UUU")
UGA=str("UGA")
UUC=str("UUC")
UUA=str("UUA")
UUG=str("UUG")
CUU=str("CUU")
CUC=str("CUC")
CUA=str("CUA")
CUG=str("CUG")
AUU=str("AUU")
AUC=str("AUC")
AUA=str("AUA")
GUU=str("GUU")
GUC=str("GUC")
GUA=str("GUA")
GUG=str("GUG")
UCU=str("UCU")
UCC=str("UCC")
UCA=str("UCA")
UCG=str("UCG")
CCU=str("CCU")
CCC=str("CCC")
UCA=str("UCA")
UCG=str("UCG")
CCU=str("CCU")
CCC=str("CCC")
CCA=str("CCA")
CCG=str("CCG")
ACU=str("ACU")
ACC=str("ACC")
ACA=str("ACA")
ACG=str("ACG")
GCU=str("GCU")
GCC=str("GCC")
GCA=str("GCA")
GCG=str("GCG")
UAU=str("UAU")
UAC=str("UAC")
UAA=str("UAA")
UAG=str("UAG")
CAU=str("CAU")
CAC=str("CAC")
CAA=str("CAA")
CAG=str("CAG")
AAU=str("AAU")
AAC=str("AAC")
AAA=str("AAA")
AAG=str("AAG")
GAU=str("GAU")
GAC=str("GAC")
GAA=str("GAA")
GAG=str("GAG")
UGU=str("UGU")
UGC=str("UGC")
UGA=str("UGA")
UGG=str("UGG")
CGU=str("CGU")
CGC=str("CGC")
CGA=str("CGA")
CGG=str("CGG")
AGU=str("AGU")
AGC=str("AGC")
AGA=str("AGA")
AGG=str("AGG")
GGU=str("GGU")
GGC=str("GGC")
GGA=str("GGA")
GGG=str("GGG")
if x==AUG:
    print("methionine")
elif x==UUU or x==UUC:
    print("phenylalanine")
elif x==UGA or x==UAA:
    print("stop codon")
elif x==UAG:
    print("stop codon")
elif x==UUA or x==UUG:
    print("leucine")
elif x==CUU or x==CUC:
    print("leucine")
elif x==CUA or x==CUG:
    print("luecine")
elif x==AUU or x==AUC:
    print("isoleucine")
elif x==AUA:
    print("isoleucine")
elif x==GUU or x==GUC:
    print("valine")
elif x==GUA or x==GUG:
    print("valine")
elif x==CCU or x==CCC:
    print("proline")
elif x==CCA or x==CCG:
    print("proline")
elif x==ACU or x==ACC:
    print("threonine")
elif x==ACA or x==ACG:
    print("threonine")
elif x==GCU or x==GCC:
    print("alanine")
elif x==GCA or x==GCG:
    print("alanine")
elif x==UAU or x==UAC:
    print("tyrosine")
elif x==CAU or x==CAC:
    print("histidine")
elif x==CAA or x==CAG:
    print("glutamine")
elif x==AAU or x==AAC:
    print("asparagine")
elif x==AAA or x==AAG:
    print("lysine")
elif x==GAU or x==GAC:
    print("asparagine")
elif x==GAA or x==GAG:
    print("glutamic acid")
elif x==UGU or x==UGC:
    print("cysteine")
elif x==UGG:
    print("typtophan")
elif x==CGU or x==CGC:
    print("argenine")
elif x==CGA or x==CGG:
    print("argenine")
elif x==AGU or x==AGC:
    print("serine")
elif x==AGA or x==AGC:
    print("argenine")
elif x==GGU or x==GGC:
    print("glycine")
elif x==GGA or x==GGG:
    print("glycine")
elif x==UCU or x==UCC:
    print("serine")
elif x==UCA or UCG:
    print("serine")  
#restriction sites for pbr322
print("restriction sites")
x=input("enter DNA sequence :")
a=GAATTC
b=GATATC
c=AAGCTT
d=GGATCC
e=CTGCAG
f=CATATG
if a in x:
    print("ecori")
if b in x:
    print("ecorv")
if c in x:
    print("hind3")
if d in x:
    print("bamh1")
if e in x:
    print("pst")
if f in x:
    print("nde1")
# Out:
# DNA SEQUENCE:
#  ATGCTACG
# REVERSE SEQUENCE FOR PROVIDED DNA IS:
#
# GCATCGTA
# Your DNA entry is :
#  ATGCTACG
# The  complement of your entry sequence is :
# TACGATGC
# The  mRNA of your entry sequence is :
# Atranscription
# Utranscription
# Gtranscription
# Ctranscription
# Utranscription
# Atranscription
# Ctranscription
# Gtranscription
# enter DNA sequence :ATGC
# U A C G translation
# enter rna sequence :AUGCUACG
# AUG
# CUA
# CG
#
#
# methionine
# serine
# codons
# enter codon :AUGCUACG
# serine
# restriction sites
# enter DNA sequence :AUGCUACG
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ecdca87a0b48> in <module>()
#     356 print("restriction sites")
#     357 x=input("enter DNA sequence :")
# --> 358 a=GAATTC
#     359 b=GATATC
#     360 c=AAGCTT
#
# NameError: name 'GAATTC' is not defined
